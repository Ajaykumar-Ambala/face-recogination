# %%
import cv2
import matplotlib.pyplot as plt

# %%
path = r"./images/lionel_messi/_111066400_messi.jpg"
img = cv2.imread(path)

# %%
img.shape
# Out:
# (576, 1024, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img,(cv2.COLOR_BGR2GRAY))
plt.imshow(gray, cmap='gray')

# %%
faces = face_CascadeClassifier(./opencv/
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 faces = face_CascadeClassifier
#
# NameError: name 'face_CascadeClassifier' is not defined
