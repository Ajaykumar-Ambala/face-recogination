# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread(r"C:\Users\Ajaykumar\sports face recogination\face recogination\model\data set\Rohit sharma\P_003.jpg")
img.shape
# Out:
# (2048, 2028, 3)

# %%
img = cv2.resize(img,(300,400))

# %%
img1 = cv2.resize(img,(600,600))
cv2.imshow("imag",img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img)
plt.show()

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray = cv2.resize(gray,(300,400))
gray.shape
# Out:
# (400, 300)

# %%
gray
# Out:
# array([[114, 114, 114, ..., 203, 201, 201],
#        [114, 114, 114, ..., 202, 201, 201],
#        [114, 114, 114, ..., 202, 200, 201],
#        ...,
#        [103, 103, 100, ...,  27,  24,  23],
#        [103, 102, 100, ...,  27,  24,  24],
#        [103, 102, 101, ...,  27,  24,  23]], shape=(400, 300), dtype=uint8)

# %%
plt.imshow(gray,cmap='gray')
plt.show()

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray,1.3,5)

faces
# Out:
# array([[ 69,  69, 136, 136]], dtype=int32)

# %%
if len(faces) > 0:
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (255,0,0), 2)
else:
    print("No face detected")

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (np.int32(69), np.int32(69), np.int32(136), np.int32(136))

# %%
face_img = cv2.rectangle(gray,(x,y),(x+w,y+h),(255,0,0),2)
cv2.imshow("face",face_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
#plt.show()

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[h:y+h,x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)


# cv2.imshow("face",face_img)
# cv2.waitKey(0)
# cv2.destroyAllWindows
plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

if len(faces) > 0:
    for i, (x, y, w, h) in enumerate(faces):
        print(f"Face {i+1}:", x, y, w, h)
        cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
else:
    print("No faces detected")
# Out:
# Face 1: 69 70 134 134

# %%
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

cv2.imshow("Faces", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

# Load Haar cascades
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_eye.xml")

# Read image
img_path =r"C:\Users\Ajaykumar\sports face recogination\face recogination\model\data set\Rohit sharma\P_003.jpg"
img = cv2.imread(img_path)
img = cv2.resize(img,(600,800))

if img is None:
    print("⚠️ Could not load image. Try converting it to .jpg or .png.")
else:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(gray, 1.1, 5)

    for (x,y,w,h) in faces:
        cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0), 2)

        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]

        eyes = eye_cascade.detectMultiScale(roi_gray, 1.1, 10)
        for (ex,ey,ew,eh) in eyes:
            cv2.rectangle(roi_color, (ex,ey), (ex+ew, ey+eh), (0,255,0), 2)

    cv2.imshow("Face & Eyes", img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2 as cv
import matplotlib.pyplot as plt

path = r"C:\Users\Ajaykumar\sports face recogination\face recogination\model\data set\Rohit sharma\P_003.jpg"
# def two_eyes_detect (img_path):
    
img1 = cv.imread(path)
img1 = cv.resize(img1,(600,600))
print(img1.shape)
gray = cv.cvtColor(img1,cv.COLOR_BGR2GRAY)
face_cascade = cv.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray,1.1,5)

(x,y,w,h) = faces[0]

for (x,y,w,h) in faces:
    face_img = cv.rectangle(gray,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[ y:y+h ,x:x+w ]
    roi_color = face_img[ y:y+h , x:x+w ]
    eyes = eye_cascade.detectMultiScale(roi_gray,1.1,10)
    for (ex,ey,ew,eh) in eyes:
        cv.rectangle(roi_color, (ex,ey), (ex+ew,ey+eh), (0,255,0), 2)
        

plt.imshow(face_img)
plt.axis('off')
# Out:
# (600, 600, 3)
# (np.float64(-0.5), np.float64(599.5), np.float64(599.5), np.float64(-0.5))

# %%
def get_cropped_image_if_2_eyes (image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray ,1.3,5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h ,x:x+w]
        roi_color = img[y:y+h ,x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >=2:
            return roi_color

        else:
            print("⚠️ No cropped image returned. Probably no face with 2 eyes detected.")

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)

    if img is None:  # path is wrong or file not readable
        print(f"⚠️ Could not read image: {image_path}")
        return None

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    for (x, y, w, h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

    print(f"⚠️ No face with 2 eyes found in: {image_path}")
    return None

# %%
import os
print(os.getcwd())
print(os.listdir("./test_image"))
# Out:
# C:\Users\Ajaykumar\sports face recogination\face recogination\model
# ['.ipynb_checkpoints', '08vk.gif', 'IMGL7092 - Copy.JPG', 'IMGL7102.JPG', 'IMGL7105.JPG', 'stevi.jpg', 'stevi2.jpg', 'vitral.jpg']

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
original_image = cv2.imread(r"C:\Users\Ajaykumar\sports face recogination\face recogination\model\test_image\stevi.jpg")

if original_image is None:
    print("⚠️ Image not found! Check the path again.")
else:
    # Convert from BGR (OpenCV) to RGB (matplotlib expects RGB)
    img_rgb = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

    plt.imshow(img_rgb, cmap='gray')  # use cmap only for grayscale images
    plt.axis("off")
    plt.show()

# %%
import matplotlib.pyplot as plt
origina_image= cv2.imread( r"C:\Users\Ajaykumar\sports face recogination\face recogination\model\test_image\stevi.jpg")
plt.imshow(original_image,cmap='gray')
plt.show()

# %%
import os

folder = r"C:\Users\Ajaykumar\sports face recogination\face recogination\model\test_image"
print(os.listdir(folder))
# Out:
# ['.ipynb_checkpoints', '08vk.gif', 'IMGL7092 - Copy.JPG', 'IMGL7102.JPG', 'IMGL7105.JPG', 'stevi.jpg', 'stevi2.jpg', 'vitral.jpg']

# %%
import cv2

path =  r"C:\Users\Ajaykumar\sports face recogination\face recogination\model\test_image\stevi2.jpg"
img = cv2.imread(path)

if img is None:
    print("⚠️ Still not found. Double-check spelling or extension.")
else:
    print("✅ Image loaded:", img.shape)
# Out:
# ✅ Image loaded: (450, 800, 3)

# %%
import matplotlib.pyplot as plt
cropped_image = get_cropped_image_if_2_eyes ( r"C:\Users\Ajaykumar\sports face recogination\face recogination\model\test_image\stevi.jpg")
plt.imshow(cropped_image)
plt.show()

# %%
# import matplotlib.pyplot as plt
ori_image_obstructed = cv2.imread(r"C:\Users\Ajaykumar\sports face recogination\face recogination\model\test_image\stevi2.jpg")
plt.imshow(ori_image_obstructed)
plt.show()

# %%
import matplotlib.pyplot as plt
import cv2

cropped_image = get_cropped_image_if_2_eyes(
    r"C:\Users\Ajaykumar\sports face recogination\face recogination\model\test_image\stevi2.jpg"
)

if cropped_image is None:
    print("⚠️ No cropped image returned. Probably no face with 2 eyes detected.")
else:
    # Convert from BGR (cv2 default) to RGB for matplotlib
    cropped_rgb = cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB)
    plt.imshow(cropped_rgb)
    plt.axis("off")
    plt.show()
# Out:
# ⚠️ No face with 2 eyes found in: C:\Users\Ajaykumar\sports face recogination\face recogination\model\test_image\stevi2.jpg
# ⚠️ No cropped image returned. Probably no face with 2 eyes detected.

# %%
path_to_data = "./images/"
path_to_cr_data = "./images/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./images/cropped',
#  './images/lionel_messi',
#  './images/maria_sharapova',
#  './images/roger_federer',
#  './images/serena_williams',
#  './images/virat_kohli']

# %%
import shutil
if os.path.exists(path_to_cr_data):
    shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    celebrity_file_names_dict[celebrity_name] = []

    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped image in folder: ", cropped_folder)

            cropped_file_name = celebrity_name + str(count) + ".jpg"
            cropped_file_path = cropped_folder + "/" + cropped_file_name

            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_name)
            count += 1
# Out:
# cropped
# lionel_messi
# Generating cropped image in folder:  ./images/cropped/lionel_messi
# ⚠️ No face with 2 eyes found in: ./images/lionel_messi\10_MESSI_JUGADORS-WEB.jpg
# ⚠️ No face with 2 eyes found in: ./images/lionel_messi\26622.jpg
# ⚠️ No face with 2 eyes found in: ./images/lionel_messi\27243622-0-image-m-13_1586991155251.jpg
# ⚠️ No face with 2 eyes found in: ./images/lionel_messi\5bd946a6cdbadfc416e59db42422c06c.jpg
# ⚠️ No face with 2 eyes found in: ./images/lionel_messi\a70652xy3tnbtsa7_1582098259.jpeg
# ⚠️ No face with 2 eyes found in: ./images/lionel_messi\bf7680a40cc24597a645b97fb80307ad500x500@2x.jpg
# ⚠️ No face with 2 eyes found in: ./images/lionel_messi\download.jfif
# ⚠️ No face with 2 eyes found in: ./images/lionel_messi\forbes-highest-paid-athletes-2019-00.jpg
# ⚠️ No face with 2 eyes found in: ./images/lionel_messi\hi-res-dd0ead86aa219346a8cc94c50c8a458d_crop_north.jpg
# ...

# %% [markdown]
# <!-- Feature Engineering -->

# %% [markdown]
# # Feature Engineering

# %%
import numpy as np
import pywt
import cv2
def w2d(img,mode='haar',level=1):
    imArray = img
    #Datatype conversions
    # coverting to grayscale
    imArray  =cv2.cvtColor(imArray,cv2.COLOR_BGR2GRAY)
    # convert to float
    imArray = np.float32(imArray)
    imArray /= 255;
    # compute coeffient
    coeffs = pywt.wavedec2(imArray,mode,level=level)

    # process coeffienit
    coeffs_H=list(coeffs)
    coeffs_H[0] *=0;

    # reconstructions
    imArray_H=pywt.waverec2(coeffs_h,mode);
    imArray_H *=255;
    imArray_H = np.uint8(imArray_H)
    return imArray_H

# %%
import numpy as np
import pywt
import cv2

def w2d(img, mode='haar', level=1):
    if img is None:
        raise ValueError("Input image is None. Please check the source.")

    # convert to grayscale
    imArray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # convert to float
    imArray = np.float32(imArray)
    imArray /= 255

    # compute coefficients
    coeffs = pywt.wavedec2(imArray, mode, level=level)

    # process coefficients
    coeffs_H = list(coeffs)
    coeffs_H[0] *= 0   # set approximation coeffs to 0

    # reconstruction
    imArray_H = pywt.waverec2(coeffs_H, mode)
    imArray_H *= 255
    imArray_H = np.uint8(imArray_H)

    return imArray_H

# %%
if cropped_image is None:
    print("cropped_image is empty. Check face detection or image path.")
else:
    im_har = w2d(cropped_image , 'db1', 5)
    plt.imshow(im_har, cmap='gray')
    plt.show()
# Out:
# cropped_image is empty. Check face detection or image path.

# %%
class_dict ={}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count=count + 1
class_dict
# Out:
# {'cropped': 0,
#  'lionel_messi': 1,
#  'maria_sharapova': 2,
#  'roger_federer': 3,
#  'serena_williams': 4,
#  'virat_kohli': 5}

# %%
import cv2
import os

path = r"C:\Users\Ajaykumar\sports face recogination\face recogination\model\images_dataset\lionel_messi\lionel_messi1.jpg"

print("Exists:", os.path.exists(path))  # should be True

img = cv2.imread(path)
print("Image loaded:", img is not None)  # should be True
if img is not None:
    print("Shape:", img.shape)
# Out:
# Exists: False
# Image loaded: False

# %%
dataset_dir = r"C:\Users\Ajaykumar\sports face recogination\face recogination\model\images"

celebrity_file_names_dict = {}

for celebrity_name in os.listdir(dataset_dir):
    celebrity_folder = os.path.join(dataset_dir, celebrity_name)
    if not os.path.isdir(celebrity_folder):
        continue
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for file in os.listdir(celebrity_folder):
        if file.lower().endswith((".jpg", ".jpeg", ".png")):
            full_path = os.path.join(celebrity_folder, file)
            celebrity_file_names_dict[celebrity_name].append(full_path)

# %%
for celeb, files in celebrity_file_names_dict.items():
    print("Celebrity:", celeb)
    for f in files[:3]:  # show first 3 files
        print("  ", f)
# Out:
# Celebrity: cropped
# Celebrity: lionel_messi
#    C:\Users\Ajaykumar\sports face recogination\face recogination\model\images\lionel_messi\02453493f852c0efe8ff951dea5845c4.jpg
#    C:\Users\Ajaykumar\sports face recogination\face recogination\model\images\lionel_messi\10_MESSI_JUGADORS-WEB.jpg
#    C:\Users\Ajaykumar\sports face recogination\face recogination\model\images\lionel_messi\1211643746.jpg.0.jpg
# Celebrity: maria_sharapova
#    C:\Users\Ajaykumar\sports face recogination\face recogination\model\images\maria_sharapova\001aa018f83f14d5a9cd30.jpg
#    C:\Users\Ajaykumar\sports face recogination\face recogination\model\images\maria_sharapova\002831aab808e5488d75de92ec4fb939.jpg
#    C:\Users\Ajaykumar\sports face recogination\face recogination\model\images\maria_sharapova\104680979-GettyImages-466647961.jpg
# Celebrity: roger_federer
#    C:\Users\Ajaykumar\sports face recogination\face recogination\model\images\roger_federer\07548250.jpg
# ...

# %%
import cv2
import numpy as np

X = []
y = []

for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            print("❌ Could not read:", training_image)
            continue
        
        try:
            # Resize raw image
            scaled_raw_img = cv2.resize(img, (32, 32))
            
            # Wavelet transform
            img_har = w2d(img, 'db1', 5)
            scaled_img_har = cv2.resize(img_har, (32, 32))
            
            # Combine features
            combined_img = np.vstack((
                scaled_raw_img.reshape(32*32*3, 1),
                scaled_img_har.reshape(32*32, 1)
            ))
            
            X.append(combined_img)
            y.append(class_dict[celebrity_name])
        
        except Exception as e:
            print(f"⚠️ Skipping {training_image}, error: {e}")

# %%
print("Total samples collected:", len(X))
print("Total labels collected:", len(y))
# print(y)
# Out:
# Total samples collected: 341
# Total labels collected: 341

# %%
32*32*3+32*32
# Out:
# 4096

# %%
len(X)
# Out:
# 341

# %% [markdown]
# len(X[0])

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (341, 4096)

# %%
X[0]
# Out:
# array([ 62.,  59.,  45., ..., 243.,   2., 255.], shape=(4096,))

# %% [markdown]
# # data cleaning is done

# %% [markdown]
# # training the model

# %% [markdown]
# We will use SVM with rbf kernel turned with heruistic fineturning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0)

pipe = Pipeline([('scaler',StandardScaler()),('svc',SVC(kernel ='rbf',C = 12))])
pipe.fit(X_train,y_train)
pipe.score(X_test,y_test)
# Out:
# 0.5465116279069767

# %%
print(classification_report(y_test,pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.50      0.27      0.35        11
#            2       0.65      0.59      0.62        22
#            3       0.75      0.35      0.48        17
#            4       0.25      0.30      0.27        10
#            5       0.55      0.85      0.67        26
#
#     accuracy                           0.55        86
#    macro avg       0.54      0.47      0.48        86
# weighted avg       0.57      0.55      0.53        86

# %%
pipe
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('svc', SVC(C=12))])

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
# C:\Users\Ajaykumar\anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Ajaykumar\anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Ajaykumar\anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# ...

# %%
from sklearn.model_selection import ParameterGrid
from tqdm import tqdm

param_grid = list(ParameterGrid(mp['params']))
for params in tqdm(param_grid, desc=f"Training {algo}"):
    pipe = make_pipeline(StandardScaler(), mp['model'])
    pipe.set_params(**params)   # ✅ works on pipeline
    pipe.fit(X_train, y_train)
    score = pipe.score(X_test, y_test)
    print(f"{params} → score={score}")
# Out:
# C:\Users\Ajaykumar\anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Training logistic_regression:  33%|██████████████████                                    | 1/3 [00:03<00:06,  3.24s/it]
# {'logisticregression__C': 1} → score=0.5
# C:\Users\Ajaykumar\anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Training logistic_regression:  67%|████████████████████████████████████                  | 2/3 [00:06<00:03,  3.47s/it]
# {'logisticregression__C': 5} → score=0.5116279069767442
# ...

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc', SVC(C=10, gamma='auto', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, multi_class='auto',
#                                      solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.5465116279069767

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.4418604651162791

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.5

# %%
best_clf =  best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 3,  1,  2,  0,  5],
#        [ 0, 13,  0,  2,  7],
#        [ 2,  2,  6,  4,  3],
#        [ 1,  3,  0,  3,  3],
#        [ 0,  1,  0,  3, 22]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# plt.show()
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'cropped': 0,
#  'lionel_messi': 1,
#  'maria_sharapova': 2,
#  'roger_federer': 3,
#  'serena_williams': 4,
#  'virat_kohli': 5}

# %% [markdown]
# ###

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# ...
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
